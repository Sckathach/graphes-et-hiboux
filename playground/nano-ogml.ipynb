# %%
let a = 3
# Out:
# val a : int = 3

# %%
let a = 2
# Out:
# val a : int = 2

# %%
#use "topfind";;
(* #require "jupyter.notebook" *)
Topfind.reset();;
#load "singeries.cmo"
# Out:
# - : unit = ()
# Findlib has been successfully loaded. Additional directives:
#   #require "package";;      to load a package
#   #list;;                   to list the available packages
#   #camlp4o;;                to load camlp4 (standard syntax)
#   #camlp4r;;                to load camlp4 (revised syntax)
#   #predicates "p,q,...";;   to set these predicates
#   Topfind.reset();;         to force that packages will be reloaded
#   #thread;;                 to enable threads
#
# - : unit = ()
# - : unit = ()

# %%
#list
# Out:
# angstrom            (version: 0.16.0)
# angstrom-lwt-unix   (version: 0.16.0)
# angstrom.async      (version: n/a)
# angstrom.lwt-unix   (version: n/a)
# angstrom.unix       (version: n/a)
# asn1-combinators    (version: 0.2.6)
# astring             (version: 0.8.5)
# astring.top         (version: 0.8.5)
# base                (version: v0.16.3)
# base.base_internalhash_types (version: v0.16.3)
# base.caml           (version: v0.16.3)
# base.md5            (version: v0.16.3)
# base.shadow_stdlib  (version: v0.16.3)
# base64              (version: 3.5.1)
# base64.rfc2045      (version: 3.5.1)
# bigarray            (version: [distributed with Ocaml])
# bigarray-compat     (version: 1.1.0)
# bigarray-overlap    (version: 0.2.1)
# bigstringaf         (version: 0.9.1)
# bos                 (version: 0.2.1)
# bos.setup           (version: 0.2.1)
# bos.top             (version: 0.2.1)
# bytes               (version: [distributed with OCaml 4.02 or above])
# ...
